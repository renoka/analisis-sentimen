# %% [markdown]
# <a href="https://colab.research.google.com/github/renoka/analisis-sentimen-web/blob/main/pengolahan_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('data_ulasan new(3).xlsx')
data
# Out:
#      Nama_Produk    Akun                                             Ulasan  \
# 0       Oppo A60   Yunus  seller response oke, pengiriman oke dan barang...
# 1       Oppo A60    ahmi                  mantul barangnya sesuai deskripsi
# 2       Oppo A60   yayan  jgn diragukan lagi belanja di toko ini. pokokn...
# 3       Oppo A60    sisi  ori segel repack berfingsi packing aman respon...
# 4       Oppo A60   arief                                Alhamdulilah sesuai
# ...          ...     ...                                                ...
# 1246     oppo 16    bowo  Tombol fisik sering macet, tidak nyaman digunakan
# 1247     oppo 16    boby  Kualitas audio buruk, suara sangat kecil dan p...
# 1248     oppo 16  guntur      Ponsel mudah sekali hang, sangat tidak stabil
# 1249     oppo 16   damar  Ponsel sering bergetar dan membuat suara aneh ...
# 1250     oppo 16   putri  Kamera depan sangat buruk, hasil foto jauh dar...
#
#       Rate
# 0      5.0
# 1      5.0
# 2      5.0
# ...

# %%
data = data.drop(columns=['Nama_Produk', 'Akun'])
data
# Out:
#                                                  Ulasan  Rate
# 0     seller response oke, pengiriman oke dan barang...   5.0
# 1                     mantul barangnya sesuai deskripsi   5.0
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0
# 3     ori segel repack berfingsi packing aman respon...   5.0
# 4                                   Alhamdulilah sesuai   5.0
# ...                                                 ...   ...
# 1246  Tombol fisik sering macet, tidak nyaman digunakan   1.0
# 1247  Kualitas audio buruk, suara sangat kecil dan p...   1.0
# 1248      Ponsel mudah sekali hang, sangat tidak stabil   1.0
# 1249  Ponsel sering bergetar dan membuat suara aneh ...   1.0
# 1250  Kamera depan sangat buruk, hasil foto jauh dar...   1.0
#
# [1251 rows x 2 columns]

# %%
# pelabelan
Pelabelan = []
for index, row in data.iterrows():
    if row['Rate'] > 3:
      Pelabelan.append('positif')
    elif row['Rate'] == 3:
      Pelabelan.append('netral')
    else :
      Pelabelan.append('negatif')

data['Label'] = Pelabelan

data
# Out:
#                                                  Ulasan  Rate    Label
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1246  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1247  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1248      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1249  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1250  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
# [1251 rows x 3 columns]

# %%
data.shape
# Out:
# (1251, 3)

# %%
data.to_csv('data baru.csv', index=False)

# %%
import pandas as pd
data = pd.read_csv('data baru.csv')
data
# Out:
#                                                  Ulasan  Rate    Label
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1246  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1247  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1248      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1249  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1250  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
# [1251 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251 entries, 0 to 1250
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ulasan  1250 non-null   object
#  1   Rate    1245 non-null   float64
#  2   Label   1251 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 29.4+ KB

# %%
data.isna()
# Out:
#       Ulasan   Rate  Label
# 0      False  False  False
# 1      False  False  False
# 2      False  False  False
# 3      False  False  False
# 4      False  False  False
# ...      ...    ...    ...
# 1246   False  False  False
# 1247   False  False  False
# 1248   False  False  False
# 1249   False  False  False
# 1250   False  False  False
#
# [1251 rows x 3 columns]

# %%
data.isna().any()
# Out:
# Ulasan     True
# Rate       True
# Label     False
# dtype: bool

# %%
data.describe()
# Out:
#               Rate
# count  1245.000000
# mean      3.026506
# std       1.489547
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max       5.000000

# %%
data.isnull().sum()
# Out:
# Ulasan    1
# Rate      6
# Label     0
# dtype: int64

# %%
data = data.dropna()
data.shape
# Out:
# (1245, 3)

# %%
data
# Out:
#                                                  Ulasan  Rate    Label
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1246  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1247  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1248      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1249  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1250  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
# [1245 rows x 3 columns]

# %%
duplikat = data[data.duplicated(subset=['Ulasan'])]
duplikat
# Out:
#                                                  Ulasan  Rate    Label
# 105   barang sudah sampai tapi blom dibuka karna blo...   5.0  positif
# 131                                     pengiriman lama   3.0   netral
# 146                                                good   5.0  positif
# 155                                              mantap   5.0  positif
# 164                                              mantap   5.0  positif
# ...                                                 ...   ...      ...
# 1146                Harga tidak sesuai dengan kualitas.   1.0  negatif
# 1147               Barang cacat, tidak layak digunakan.   1.0  negatif
# 1212                   kenapa cepet banget panas HP nya   1.0  negatif
# 1213                         Pelayanan jelek dan lambat   1.0  negatif
# 1223                               sangat mengecewakan.   1.0  negatif
#
# [128 rows x 3 columns]

# %%
data = data.drop_duplicates(subset=['Ulasan'], keep='first')
data
# Out:
#                                                  Ulasan  Rate    Label
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1246  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1247  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1248      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1249  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1250  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
# [1117 rows x 3 columns]

# %%
data = data.to_csv('data clean.csv', index=False)

# %% [markdown]
# #Preprocessing data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data clean.csv')
data.shape
# Out:
# (1117, 3)

# %%
data
# Out:
#                                                  Ulasan  Rate    Label
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1112  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1113  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1114      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1115  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1116  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
# [1117 rows x 3 columns]

# %%
# case folding
import re
def clean_text(data, text_field, new_text_field_name):
  data[new_text_field_name] = data[text_field].str.lower()
  data[new_text_field_name] = data[new_text_field_name].apply(lambda elem: re.sub(r"[^a-zA-Z0-9]", " ", elem))
  data[new_text_field_name] = data[new_text_field_name].apply(lambda elem: re.sub(r"\d+", " ", elem))
  return data
data['case_folding'] = data['Ulasan'].str.lower()
data['case_folding']
data = clean_text(data, 'Ulasan', 'case_folding')
data.head(10)
# Out:
#                                               Ulasan  Rate    Label  \
# 0  seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                  mantul barangnya sesuai deskripsi   5.0  positif
# 2  jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3  ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                Alhamdulilah sesuai   5.0  positif
# 5  Barangnya original 👍 Ada garansi resmi Warna s...   5.0  positif
# 6  Barangnya original 👍 plastik luar tersegel, ta...   5.0  positif
# 7  barangnya sesuai dengan gambar pengiriman nya ...   5.0  positif
# 8    mantap...barang yg di pesan sesuai..terimakasih   5.0  positif
# 9                                     pembelian ke-3   5.0  positif
#
#                                         case_folding
# 0  seller response oke  pengiriman oke dan barang...
# 1                  mantul barangnya sesuai deskripsi
# 2  jgn diragukan lagi belanja di toko ini  pokokn...
# ...

# %%
# tokenizing
from nltk.tokenize import RegexpTokenizer
regexp = RegexpTokenizer(r'\w+|$[0-9]+|\S+')
data['token'] = data['case_folding'].apply(regexp.tokenize)
data.head(20)
# Out:
#                                                Ulasan  Rate    Label  \
# 0   seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                   mantul barangnya sesuai deskripsi   5.0  positif
# 2   jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3   ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                 Alhamdulilah sesuai   5.0  positif
# 5   Barangnya original 👍 Ada garansi resmi Warna s...   5.0  positif
# 6   Barangnya original 👍 plastik luar tersegel, ta...   5.0  positif
# 7   barangnya sesuai dengan gambar pengiriman nya ...   5.0  positif
# 8     mantap...barang yg di pesan sesuai..terimakasih   5.0  positif
# 9                                      pembelian ke-3   5.0  positif
# 10                                 kemasan cukup rapi   3.0   netral
# 11          barang nya bagus, sesuai pesanan original   5.0  positif
# 12           barang sesuai dengan pesanan terimakasih   5.0  positif
# ...

# %%
# normalisasi
normalisasi_kata = pd.read_csv('normalisasi.csv', encoding='latin1', delimiter=';')
normalisasi_kata_dict = {}
for index, row in normalisasi_kata.iterrows():
  if row[0] not in normalisasi_kata_dict:
      normalisasi_kata_dict[row[0]] = row[1]

def normalized_term(document):
  return [normalisasi_kata_dict[term] if term in normalisasi_kata_dict else term for term in document]
data['Normalisasi'] = data['token'].apply(normalized_term)
data
# Out:
# <ipython-input-23-95a05877d2f2>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalisasi_kata_dict:
# <ipython-input-23-95a05877d2f2>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalisasi_kata_dict[row[0]] = row[1]
#                                                  Ulasan  Rate    Label  \
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# stopword
from nltk.corpus import stopwords
stopword = stopwords.words('indonesian')
csv_stopword = pd.read_csv('stopwords.csv', names=['stopwords'], header=None)

stopword.extend(['oke', 'kl', 'en', 'nya', 'dah', 'si', 'okk', 'boz', 'om', 'i', 'as', 'b', 'k' 'markotop', 'ko', 'yah', 'gan', 'and', 'sih','beth','cuuyyy','ya','s',
                 'okee','dech','mase','nich','di','siihh','ok','dak','ha','bss','okokok','bos','boss','ku','annya','astagfirulloh','loh','an','sameday','bosss','ka','hahaha',
                 'kamsiaaa','feb','wl','ehhh','alhamdulillaah','eman','sok','gaess','goks','kk','dh','yaa','nyah','nyh','kn','bosque','ngrejekeni','han','hehee','josss',
                 'ter','euyy','y','tn','jxxxs','tok','wkwkwkwk','wow','samday','kek','bang','gw','na','mah','jum','at','sich','eh','tuh','wkwk','btw','ye','iya','f',
                 'nih','hmmm','allah','sik','gaes','h','vs','lo','ehh','nge',''])
stopword.extend(csv_stopword['stopwords'][0].split('.'))
stopword = set(stopword)

def stopwords(text):
  text = [word for word in text if word not in stopword]
  return text
data['Stopwords']  = data['Normalisasi'].apply(stopwords)
data
# Out:
#                                                  Ulasan  Rate    Label  \
# 0     seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                     mantul barangnya sesuai deskripsi   5.0  positif
# 2     jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3     ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                   Alhamdulilah sesuai   5.0  positif
# ...                                                 ...   ...      ...
# 1112  Tombol fisik sering macet, tidak nyaman digunakan   1.0  negatif
# 1113  Kualitas audio buruk, suara sangat kecil dan p...   1.0  negatif
# 1114      Ponsel mudah sekali hang, sangat tidak stabil   1.0  negatif
# 1115  Ponsel sering bergetar dan membuat suara aneh ...   1.0  negatif
# 1116  Kamera depan sangat buruk, hasil foto jauh dar...   1.0  negatif
#
#                                            case_folding  \
# 0     seller response oke  pengiriman oke dan barang...
# ...

# %%
# !pip install sastrawi
# !pip install swifter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 14.3 MB/s eta 0:00:00
# ...
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=f3b57857be04f69b821083f7fc1f7f00fc6e15ad38917efe8f569f11a50dfe22
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# ...

# %%
# stemming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemmed_wrapper(term):
  return stemmer.stem(term)
term_dict ={}

tokped = data['Stopwords']
for doc in tokped:
  for term in doc:
    if term not in term_dict:
      term_dict[term] = ' '
for term in term_dict:
  term_dict[term] = stemmed_wrapper(term)
  print(term, ':', term_dict[term])

  print(len(term_dict))
  print('....................')
# Out:
# seller : seller
# 1312
# ....................
# response : response
# 1312
# ....................
# pengiriman : kirim
# 1312
# ....................
# barang : barang
# 1312
# ....................
# bagus : bagus
# 1312
# ....................
# mantap betul : mantap betul
# 1312
# ....................
# barangnya : barang
# 1312
# ....................
# sesuai : sesuai
# 1312
# ....................
# deskripsi : deskripsi
# 1312
# ....................
# diragukan : ragu
# 1312
# ....................
# belanja : belanja
# 1312
# ....................
# toko : toko
# 1312
# ....................
# pokoknya : pokok
# 1312
# ....................
# top : top
# 1312
# ....................
# markotop : markotop
# 1312
# ....................
# terima kasih : terima kasih
# 1312
# ....................
# sukses : sukses
# 1312
# ....................
# ori : ori
# 1312
# ....................
# segel : segel
# 1312
# ....................
# repack : repack
# 1312
# ....................
# ...

# %%
def get_stemmed_term(doc):
  return [term_dict[term] for term in doc]

data['Stemmer'] = data['Stopwords'].apply(get_stemmed_term)
data.head(10)
# Out:
#                                               Ulasan  Rate    Label  \
# 0  seller response oke, pengiriman oke dan barang...   5.0  positif
# 1                  mantul barangnya sesuai deskripsi   5.0  positif
# 2  jgn diragukan lagi belanja di toko ini. pokokn...   5.0  positif
# 3  ori segel repack berfingsi packing aman respon...   5.0  positif
# 4                                Alhamdulilah sesuai   5.0  positif
# 5  Barangnya original 👍 Ada garansi resmi Warna s...   5.0  positif
# 6  Barangnya original 👍 plastik luar tersegel, ta...   5.0  positif
# 7  barangnya sesuai dengan gambar pengiriman nya ...   5.0  positif
# 8    mantap...barang yg di pesan sesuai..terimakasih   5.0  positif
# 9                                     pembelian ke-3   5.0  positif
#
#                                         case_folding  \
# 0  seller response oke  pengiriman oke dan barang...
# 1                  mantul barangnya sesuai deskripsi
# 2  jgn diragukan lagi belanja di toko ini  pokokn...
# ...

# %%
data = data.to_csv('data hasil preprocessing(3).csv', index=False)
